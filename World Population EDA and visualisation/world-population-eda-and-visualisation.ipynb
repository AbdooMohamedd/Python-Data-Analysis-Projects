# %% [markdown]
# # 1 - import libraries and Read Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### About the Dataset
#
# 1- Rank: The ranking of the country or territory based on some criteria (not specified in the provided data).
#
# 2- CCA3: The three-letter country code as per the ISO 3166-1 alpha-3 standard.
#
# 3- Country/Territory: The name of the country or territory.
#
# 4- Capital: The capital city of the country or territory.
#
# 5- Continent: The continent to which the country or territory belongs.
#
# 6- Population data for the years 2022, 2020, 2015, 2010, 2000, 1990, 1980, and 1970.
#
# 7- Area (km²): The land area of the country or territory in square kilometers.
#
# 8- Density (per km²): The population density, i.e., the number of people per square kilometer of land area.
#
# 9- Growth Rate: The annual population growth rate.
#
# 10- World Population Percentage: The percentage of the world's population that the country or territory represents.

# %%
df = pd.read_csv('world_population.csv')
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
# see the dataframe head
df.head(20)
# Out:
#     Rank CCA3    Country/Territory           Capital      Continent  \
# 0     36  AFG          Afghanistan             Kabul           Asia
# 1    138  ALB              Albania            Tirana         Europe
# 2     34  DZA              Algeria           Algiers         Africa
# 3    213  ASM       American Samoa         Pago Pago        Oceania
# 4    203  AND              Andorra  Andorra la Vella         Europe
# 5     42  AGO               Angola            Luanda         Africa
# 6    224  AIA             Anguilla        The Valley  North America
# 7    201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8     33  ARG            Argentina      Buenos Aires  South America
# 9    140  ARM              Armenia           Yerevan           Asia
# 10   198  ABW                Aruba        Oranjestad  North America
# 11    55  AUS            Australia          Canberra        Oceania
# 12    99  AUT              Austria            Vienna         Europe
# ...

# %%
# the shape of the dataframe
df.shape
# Out:
# (234, 17)

# %%
# see the summary information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.rename(columns={"id": "ID"}, inplace=True)
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
# see the describtion of the numeric columns in the datafeame
print(f"Summary Of The Dataset with numerical columns :")

pd.options.display.float_format = '{:.2f}'.format
description = df.describe()
description
# Out:
# Summary Of The Dataset with numerical columns :
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           234.00           234.00           234.00
# mean  117.50      34074414.71      33501070.95      31729956.24
# std    67.69     136766424.80     135589876.92     130404992.75
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        415284.50        404676.00
# 50%   117.50       5559944.50       5493074.50       5307400.00
# 75%   175.75      22476504.75      21447979.50      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           234.00           234.00           234.00           234.00
# mean       29845235.03      26269468.82      22710220.79      18984616.97
# std       124218487.63     111698206.72      97832173.35      81785186.08
# ...

# %%
# see the describtion of the catergorical columns in the datafeame

print("Summary Of The Dataset with catergorical columns :")
df.describe(include='object')
# Out:
# Summary Of The Dataset with catergorical columns :
#        CCA3 Country/Territory Capital Continent
# count   234               234     234       234
# unique  234               234     234         6
# top     AFG       Afghanistan   Kabul    Africa
# freq      1                 1       1        57

# %% [markdown]
# # 2 - Data cleaning

# %%
# Identify and remove duplicates.
print("there is no duplicates")
duplicates = df.duplicated()
df[duplicates]
# Out:
# there is no duplicates
# Empty DataFrame
# Columns: [Rank, CCA3, Country/Territory, Capital, Continent, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %%
# Identify and deal with missing values in the data.
print(f'we can see that there is no null values in our dataframe. ')
df.isnull().sum()
# Out:
# we can see that there is no null values in our dataframe.
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
# see how many unique values in our columns

print(f'we can see that Continent column have 6 and thats makes sense (becouse we have only 6 Continents). ')
df.nunique()
# Out:
# we can see that Continent column have 6 and thats makes sense (becouse we have only 6 Continents).
# Rank                           234
# CCA3                           234
# Country/Territory              234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
# order our data by 2022 population in descending order and set Rank as index
df = df.sort_values(by = '2022 Population', ascending = False)
df.set_index('Rank', inplace = True)
df
# Out:
#      CCA3 Country/Territory           Capital      Continent  2022 Population  \
# Rank
# 1     CHN             China           Beijing           Asia       1425887337
# 2     IND             India         New Delhi           Asia       1417173173
# 3     USA     United States  Washington, D.C.  North America        338289857
# 4     IDN         Indonesia           Jakarta           Asia        275501339
# 5     PAK          Pakistan         Islamabad           Asia        235824862
# ...   ...               ...               ...            ...              ...
# 230   MSR        Montserrat            Brades  North America             4390
# 231   FLK  Falkland Islands           Stanley  South America             3780
# 232   NIU              Niue             Alofi        Oceania             1934
# 233   TKL           Tokelau          Nukunonu        Oceania             1871
# 234   VAT      Vatican City      Vatican City         Europe              510
#
# ...

# %% [markdown]
# # 3 - Answear Some Questions on World Population

# %%
# 1- Which country has the highest population in 2022?
print('Which country has the highest population in 2022?')
most_populated_country = df[df['2022 Population'] == df['2022 Population'].max()]
print(f"Most Populated Country: ")
most_populated_country.iloc[:, 1]
# Out:
# Which country has the highest population in 2022?
# Most Populated Country:
# Rank
# 1    China
# Name: Country/Territory, dtype: object

# %%
# 2- What is the average population growth rate across all countries?
print("What is the average population growth rate across all countries?")
average_growth_rate = df['Growth Rate'].mean()
print(f"Average Population Growth Rate: {average_growth_rate:.4f}")
# Out:
# What is the average population growth rate across all countries?
# Average Population Growth Rate: 1.0096

# %%
# 3- What are the top 5 most populated continents in 2022?
print("What are the top 5 most populated continents in 2022?")
top_continents = df.groupby('Continent')['2022 Population'].sum().nlargest(5).index
print("Top 5 Most Populated Continents:", ', '.join(top_continents))
# Out:
# What are the top 5 most populated continents in 2022?
# Top 5 Most Populated Continents: Asia, Africa, Europe, North America, South America

# %%
# 4- Which country had the highest population growth rate in 2022?
print('Which country had the highest population growth rate in 2022?')
highest_growth_country = df[df['Growth Rate'] == df['Growth Rate'].max()]
print(f"Highest Growth Rate Country: ")
highest_growth_country.iloc[:, 1]
# Out:
# Which country had the highest population growth rate in 2022?
# Highest Growth Rate Country:
# Rank
# 135    Moldova
# Name: Country/Territory, dtype: object

# %%
# 5- What is the average population density across all countries in 2022?
print("What is the average population density across all countries in 2022?")
average_density = df['2022 Population'].sum() / df['Area (km²)'].sum()
print(f"Average Population Density: {average_density:.2f} people/km²")
# Out:
# What is the average population density across all countries in 2022?
# Average Population Density: 58.60 people/km²

# %%
# 6- Which countries have a population density higher than 500 people per km² in 2022?
print("Which countries have a population density higher than 500 people per km² in 2022?")
high_density_countries = df[df['2022 Population'] / df['Area (km²)'] > 500]
print(f"Countries with Population Density > 500 people/km²: ")
high_density_countries.iloc[:, 1]
# Out:
# Which countries have a population density higher than 500 people per km² in 2022?
# Countries with Population Density > 500 people/km²:
# Rank
# 8            Bangladesh
# 29          South Korea
# 57               Taiwan
# 76               Rwanda
# 104           Hong Kong
# 113           Singapore
# 119             Lebanon
# 122           Palestine
# 154             Bahrain
# 157           Mauritius
# 167               Macau
# 173               Malta
# 174            Maldives
# 182             Mayotte
# 186            Barbados
# 195              Jersey
# 198               Aruba
# 206             Bermuda
# 207            Guernsey
# 214        Sint Maarten
# 217              Monaco
# 218          San Marino
# 219           Gibraltar
# 220        Saint Martin
# 225               Nauru
# 228    Saint Barthelemy
# 234        Vatican City
# Name: Country/Territory, dtype: object

# %%
# 7- Which country has the lowest population in 2022?
print("Which country has the lowest population in 2022?")
lowest_population_country = df[df['2022 Population'] == df['2022 Population'].min()]
print(f"Lowest Population Country: ")
lowest_population_country.iloc[:, 1]
# Out:
# Which country has the lowest population in 2022?
# Lowest Population Country:
# Rank
# 234    Vatican City
# Name: Country/Territory, dtype: object

# %%
# 8- What is the percentage change in population for China from 2020 to 2022?
print("What is the percentage change in population for China from 2020 to 2022?")
china_population_2020 = df[df['Country/Territory'] == 'China']['2020 Population'].values[0]
china_population_2022 = df[df['Country/Territory'] == 'China']['2022 Population'].values[0]
percentage_change = ((china_population_2022 - china_population_2020) / china_population_2020) * 100
print(f"Percentage Change in Population for China (2020-2022): {percentage_change:.2f}%")
# Out:
# What is the percentage change in population for China from 2020 to 2022?
# Percentage Change in Population for China (2020-2022): 0.07%

# %%
# 9- What is the change in population for China from 2020 to 2022?
print("What is the percentage change in population for China from 2020 to 2022?")
china_population_2020 = df[df['Country/Territory'] == 'China']['2020 Population'].values[0]
china_population_2022 = df[df['Country/Territory'] == 'China']['2022 Population'].values[0]
change = ((china_population_2022 - china_population_2020) ) 
print(f"Change in Population for China (2020-2022): {change:.0f} Person")
# Out:
# What is the percentage change in population for China from 2020 to 2022?
# Change in Population for China (2020-2022): 957556 Person

# %%
# 10- What is the total land area of all countries in Asia?
print("What is the total land area of all countries in Asia?")
total_land_area_asia = df[df['Continent'] == 'Asia']['Area (km²)'].sum()
print(f"Total Land Area of Countries in Asia: {total_land_area_asia:,} km²")
# Out:
# What is the total land area of all countries in Asia?
# Total Land Area of Countries in Asia: 32,138,141 km²

# %%
# 11- Calculate the population growth rate for each country from 2010 to 2022.
print("Calculate the population growth rate for each country from 2010 to 2022.")
df['Population Growth Rate'] = (df['2022 Population'] - df['2010 Population']) / df['2010 Population']
print("Population Growth Rate for Each Country from 2010 to 2022:")
df[['Country/Territory', 'Population Growth Rate']]
# Out:
# Calculate the population growth rate for each country from 2010 to 2022.
# Population Growth Rate for Each Country from 2010 to 2022:
#      Country/Territory  Population Growth Rate
# Rank
# 1                China                    0.06
# 2                India                    0.14
# 3        United States                    0.09
# 4            Indonesia                    0.13
# 5             Pakistan                    0.21
# ...                ...                     ...
# 230         Montserrat                   -0.11
# 231   Falkland Islands                    0.19
# 232               Niue                    0.07
# 233            Tokelau                    0.37
# 234       Vatican City                   -0.14
#
# [234 rows x 2 columns]

# %% [markdown]
# # 4 - Exploratoy Data Analysis

# %% [markdown]
# ''' The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
#
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# '''

# %%
# check the correlations between all the numeric columns

df.corr(numeric_only  = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15776\2493635868.py in <module>
#       1 # check the correlations between all the numeric columns
#       2
# ----> 3 df.corr(numeric_only  = True)
#
# TypeError: corr() got an unexpected keyword argument 'numeric_only'

# %%
# make a heatmap about the correlations
sns.heatmap(df.corr(numeric_only = True), annot = True)

plt.rcParams['figure.figsize'] = (20 ,7)

plt.show()

# %%
# make a plot for Population Distribution by Continent
grouped_df = df.groupby('Continent').sum(numeric_only=True).sort_values(by="2022 Population", ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(grouped_df.index, grouped_df['2022 Population'], color='skyblue', edgecolor='black')
plt.xlabel('Continent')
plt.ylabel('Population (2022)')
plt.title('Bar Population Distribution by Continent 2022')
plt.xticks(rotation=45)
plt.grid(True)

# Adding data labels above each bar
for i, v in enumerate(grouped_df['2022 Population']):
    plt.text(i, v + 500000, str(v), ha='center', va='bottom', fontsize=9)

plt.show()

# %%
# create a pie graph for Population Distribution by Continent (2022)

grouped_df = df.groupby('Continent').sum(numeric_only=True).sort_values(by="2022 Population", ascending=False)

labels = grouped_df.index.tolist()
sizes = grouped_df["2022 Population"].tolist()

plt.figure(figsize=(10, 8))  
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=180)  
plt.axis('equal')  
plt.title("Pie chart Population Distribution by Continent Percent (2022) ")  
plt.show()

# %%
# Group the data by continent and calculate the sum of population for each year
grouped_data = df.groupby('Continent').agg({
    '2022 Population': 'sum',
    '2020 Population': 'sum',
    '2015 Population': 'sum',
    '2010 Population': 'sum',
    '2000 Population': 'sum',
    '1990 Population': 'sum',
    '1980 Population': 'sum',
    '1970 Population': 'sum'
}).reset_index()

years = ['2022', '2020', '2015', '2010', '2000', '1990', '1980', '1970']

fig, axes = plt.subplots(2, 4, figsize=(15, 10), sharex=True, sharey=True)
axes = axes.ravel()

# Loop through the years and create a scatter plot for each continent
for i, year in enumerate(years):
    axes[i].scatter(grouped_data['Continent'], grouped_data[year + ' Population'])
    axes[i].set_title(year)
    axes[i].set_xlabel('Continent')
    axes[i].set_ylabel('Population')
    axes[i].set_xticks(range(len(grouped_data['Continent'])))
    axes[i].set_xticklabels(grouped_data['Continent'], rotation=90)

plt.tight_layout()
plt.show()

# %%
# 'Population by Continent (1970-2022)'

data = {
    "Continent": df['Continent'],
    "1970 Population": df['1970 Population'],
    "1980 Population": df['1980 Population'],
    "1990 Population": df['1990 Population'],
    "2000 Population": df['2000 Population'],
    "2010 Population": df['2010 Population'],
    "2015 Population": df['2015 Population'],
    "2020 Population": df['2020 Population'],
    "2022 Population": df['2022 Population']
}

df_pop_by_continent = pd.DataFrame(data)

# Plotting
years = df_pop_by_continent.columns[1:]  
plt.figure(figsize=(20, 6))
for continent in df_pop_by_continent["Continent"].unique():
    continent_data = df_pop_by_continent[df_pop_by_continent["Continent"] == continent].iloc[0, 1:]
    plt.plot(years, continent_data, label=continent)

plt.title('Population by Continent (1970-2022)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting a horizontal bar chart to show the top 5 countries with the largest population in 2022
top_5_population = df.nlargest(10, '2022 Population')

plt.figure(figsize=(10, 6))
bars = plt.barh(top_5_population['Country/Territory'], top_5_population['2022 Population'], color='skyblue', edgecolor='black')

plt.xlabel('Population (2022)')
plt.ylabel('Country/Territory')
plt.title('Top 10 Countries with Largest Population in 2022')
plt.grid(axis='x')

# Adding data labels on the bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + 1000000, bar.get_y() + bar.get_height() / 2, f'{width:,}', ha='left', va='center', fontsize=9)

plt.show()

# %%
# Plot a line chart of the population growth rate for individual countries to identify trends.
x = df['Country/Territory'].head(20)
y = df['Growth Rate'].head(20)
plt.figure(figsize=(20, 6))
plt.plot(x, y, marker='o', markersize=8, color='skyblue', linewidth=2)
plt.xlabel('Country/Territory')
plt.ylabel('Growth Rate')
plt.title('Population Growth Rate for 20 Countries')
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
# Visualize the top 10 most densely populated countries on a world map

x = df['Country/Territory'].head(10)
y = df['Density (per km²)'].head(10)
plt.figure(figsize=(10, 6))
plt.bar(x, y, color='lightblue', edgecolor='black')
plt.xlabel('Country/Territory')
plt.ylabel('Population Density (per km²)')
plt.title('Population Density Comparison by Country')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
N = 20  
top_countries = df.sort_values(by='2022 Population', ascending=False).head(N)

pivot_df = top_countries.pivot(index='Country/Territory', columns='Continent', values='2022 Population')
pivot_df.plot(kind='bar', stacked=True, colormap='tab20', edgecolor='black')
plt.xlabel('Country/Territory')
plt.ylabel('Population (2022)')
plt.title(f'Population of Top {N} Most Populated Countries by Continent (2022)')
plt.xticks(rotation=45)
plt.legend(title='Continent', loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

x = df['Country/Territory'].head(20)
y = df['2022 Population'].head(20)

# Plot the scatter plot with country names and numbers on y-axis
marker_sizes = df['2022 Population'] / 50000  
for i, country in enumerate(x):
    plt.scatter(country, y.iloc[i], s=(marker_sizes.iloc[i])/20, label=country, alpha=0.7)

# Set y-axis to display numbers in billions
plt.ticklabel_format(style='plain', axis='y', useOffset=False, scilimits=(9, 9))

plt.xlabel('Country/Territory')
plt.ylabel('Population (2022)')
plt.title('Scatter Plot of 2022 Population for Most 20 populated countries')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 8))

x = df['Country/Territory'].head(20)
y = df['2022 Population'].head(20)

# Plot the scatter plot with country names and numbers on y-axis
marker_sizes = df['2022 Population'] / 50000  
for i, country in enumerate(x):
    plt.scatter(country, y.iloc[i], s=(marker_sizes.iloc[i])/20, label=country, alpha=0.7)
    plt.text(country, y.iloc[i], f'{y.iloc[i]:,.0f}', ha='center', va='bottom', rotation='vertical', fontsize=10, color='black')

# Set y-axis to display numbers in billions
plt.ticklabel_format(style='plain', axis='y', useOffset=False, scilimits=(9, 9))

plt.xlabel('Country/Territory')
plt.ylabel('Population (2022)')
plt.title('Scatter Plot of 2022 Population for Most 20 populated countries')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(20, 10))

N = 20  
top_countries = df.sort_values(by='2022 Population', ascending=False).head(N)

plt.plot(top_countries['Country/Territory'], top_countries['Growth Rate'], marker='o', markersize=8, color='skyblue', linewidth=3)
plt.xlabel('Country/Territory')
plt.ylabel('Growth Rate')
plt.title(f'Population Growth Rate for Top {N} Countries (2022)')
plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Plotting a world map to visualize the top 10 countries with the largest land area
import geopandas as gpd

world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
merged_data = world_map.merge(df, left_on='name', right_on='Country/Territory')

plt.figure(figsize=(12, 8))
merged_data.plot(column='Area (km²)', cmap='OrRd', legend=True, edgecolor='black')
plt.title('Top 10 Countries with Largest Land Area')
plt.axis('off')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15776\1094533981.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# Plotting a heatmap to show the correlation between population growth rate and land area
correlation_matrix = df[['Growth Rate', 'Area (km²)']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, cmap='coolwarm', fmt='.2f')
plt.title('Correlation between Population Growth Rate and Land Area')
plt.show()

# %%
# 'Population by Continent (1970-2022)'

data = {
    "Continent": df['Continent'],
    "1970 Population": df['1970 Population'],
    "1980 Population": df['1980 Population'],
    "1990 Population": df['1990 Population'],
    "2000 Population": df['2000 Population'],
    "2010 Population": df['2010 Population'],
    "2015 Population": df['2015 Population'],
    "2020 Population": df['2020 Population'],
    "2022 Population": df['2022 Population']
}

df = pd.DataFrame(data)

# Plotting
years = df.columns[1:]  # Extract years from columns
plt.figure(figsize=(20, 6))
for continent in df["Continent"].unique():
    continent_data = df[df["Continent"] == continent].iloc[0, 1:]
    plt.plot(years, continent_data, label=continent)

plt.title('Population by Continent (1970-2022)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Please DON'T Forget To Leave a Heart
